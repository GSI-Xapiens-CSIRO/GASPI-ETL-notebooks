# %% [markdown]
# # Download and analyse authentication log events
#
# ## Downloading log events
#
# We are going to analyse the log events of all users.
#
# To perform this task, you must have aws console access, because the keys are needed to access aws console via the cli.

# %% [markdown]
# Run the following cell to download all cloudtrail events for the time interval defined.

# %%
# %%file download_auth_trails_all.sh
#
# REGION="ap-southeast-2"
#
# #!/bin/bash
# aws cloudtrail lookup-events \
#   --lookup-attributes AttributeKey=EventName,AttributeValue=InitiateAuth \
#   --start-time 2025-05-01T00:00:00Z \
#   --end-time 2025-05-22T23:59:59Z \
#   --region $REGION \
#   --output json > auth_trails_all.json
#
# aws cloudtrail lookup-events \
#   --lookup-attributes AttributeKey=EventName,AttributeValue=RevokeToken \
#   --start-time 2025-05-01T00:00:00Z \
#   --end-time 2025-05-22T23:59:59Z \
#   --region $REGION \
#   --output json > revoke_token_trails_all.json
# Out:
# Writing download_auth_trails_all.sh

# %%
# Run follwing command with keys in the terminal
# bash download_auth_trails_all.sh

# %% [markdown]
# ## Loading the events and print them

# %%
import json
from pprint import pprint

with open("auth_trails_all.json", "r") as file:
    data = json.load(file)

for event in data["Events"]:
    cloudtrail_event = json.loads(event["CloudTrailEvent"])

    try:
        if cloudtrail_event["requestParameters"]["authFlow"] == "USER_PASSWORD_AUTH":
            print(f'User password auth attempted by user "{cloudtrail_event["additionalEventData"]["sub"]}" at {cloudtrail_event["eventTime"]}')
    except KeyError:
        pass
# Out:
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-22T01:53:31Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-22T01:53:06Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-22T01:52:09Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-22T01:51:10Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-22T01:35:11Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-22T01:20:47Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-22T01:20:44Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-22T01:20:40Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-21T23:50:50Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-21T13:14:12Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-21T07:50:52Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-21T03:31:05Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-20T06:41:03Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-20T04:22:12Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-20T02:11:31Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-20T00:03:52Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-19T06:15:16Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-19T02:03:18Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-16T10:04:04Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-16T05:34:08Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-16T03:32:48Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-16T01:30:29Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-15T07:59:02Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-15T05:40:20Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-14T23:15:46Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-14T06:08:17Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-13T05:28:14Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-13T05:21:45Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-13T05:03:26Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-13T03:17:50Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-12T01:44:16Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-09T04:38:04Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-09T02:43:13Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-09T02:06:46Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-08T07:27:42Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-08T03:53:58Z
# User password auth attempted by user "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" at 2025-05-07T22:05:57Z
# User password auth attempted by user "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" at 2025-05-07T10:08:33Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-07T01:26:37Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-06T09:40:11Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-06T07:31:29Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-06T07:30:37Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-06T01:19:54Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-04T23:46:24Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-02T07:51:08Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-02T06:24:25Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-02T06:17:44Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-02T05:19:53Z
# User password auth attempted by user "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" at 2025-05-02T04:49:08Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-02T03:15:19Z
# User password auth attempted by user "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" at 2025-05-02T02:47:24Z
# User password auth attempted by user "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" at 2025-05-02T02:14:16Z
# User password auth attempted by user "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" at 2025-05-01T23:52:15Z
# User password auth attempted by user "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" at 2025-05-01T08:07:00Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-01T06:55:54Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-01T04:36:35Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-01T01:53:39Z
# User password auth attempted by user "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" at 2025-05-01T01:20:20Z
# User password auth attempted by user "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" at 2025-05-01T01:20:16Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-01T01:19:48Z
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-01T01:19:44Z

# %%
import json
from pprint import pprint

with open("auth_trails_all.json", "r") as file:
    data = json.load(file)

for event in data["Events"]:
    cloudtrail_event = json.loads(event["CloudTrailEvent"])

    try:
        if cloudtrail_event["requestParameters"]["authFlow"] == "USER_PASSWORD_AUTH":
            print(f'User password auth attempted by user "{cloudtrail_event["additionalEventData"]["sub"]}" at {cloudtrail_event["eventTime"]}')
            if error:= cloudtrail_event.get("errorMessage"):
                print(f'\tError: {error}')
            else:
                print(f'\tSucceeded')
    except KeyError:
        pass
# Out:
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-22T01:53:31Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-22T01:53:06Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-22T01:52:09Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-22T01:51:10Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-22T01:35:11Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-22T01:20:47Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-22T01:20:44Z
# 	Error: Incorrect username or password.
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-22T01:20:40Z
# 	Error: Incorrect username or password.
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-21T23:50:50Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-21T13:14:12Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-21T07:50:52Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-21T03:31:05Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-20T06:41:03Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-20T04:22:12Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-20T02:11:31Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-20T00:03:52Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-19T06:15:16Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-19T02:03:18Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-16T10:04:04Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-16T05:34:08Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-16T03:32:48Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-16T01:30:29Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-15T07:59:02Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-15T05:40:20Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-14T23:15:46Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-14T06:08:17Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-13T05:28:14Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-13T05:21:45Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-13T05:03:26Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-13T03:17:50Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-12T01:44:16Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-09T04:38:04Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-09T02:43:13Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-09T02:06:46Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-08T07:27:42Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-08T03:53:58Z
# 	Succeeded
# User password auth attempted by user "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" at 2025-05-07T22:05:57Z
# 	Succeeded
# User password auth attempted by user "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" at 2025-05-07T10:08:33Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-07T01:26:37Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-06T09:40:11Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-06T07:31:29Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-06T07:30:37Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-06T01:19:54Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-04T23:46:24Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-02T07:51:08Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-02T06:24:25Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-02T06:17:44Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-02T05:19:53Z
# 	Succeeded
# User password auth attempted by user "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" at 2025-05-02T04:49:08Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-02T03:15:19Z
# 	Succeeded
# User password auth attempted by user "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" at 2025-05-02T02:47:24Z
# 	Succeeded
# User password auth attempted by user "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" at 2025-05-02T02:14:16Z
# 	Succeeded
# User password auth attempted by user "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" at 2025-05-01T23:52:15Z
# 	Succeeded
# User password auth attempted by user "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" at 2025-05-01T08:07:00Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-01T06:55:54Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-01T04:36:35Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-01T01:53:39Z
# 	Succeeded
# User password auth attempted by user "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" at 2025-05-01T01:20:20Z
# 	Succeeded
# User password auth attempted by user "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" at 2025-05-01T01:20:16Z
# 	Error: Incorrect username or password.
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-01T01:19:48Z
# 	Succeeded
# User password auth attempted by user "f98e24c8-2011-70ae-9d93-084eb3f4b282" at 2025-05-01T01:19:44Z
# 	Error: Incorrect username or password.

# %%
import json
from pprint import pprint

with open("revoke_token_trails_all.json", "r") as file:
    data = json.load(file)

for event in data["Events"]:
    cloudtrail_event = json.loads(event["CloudTrailEvent"])

    try:
        print(f'User "{cloudtrail_event["additionalEventData"]["sub"]}" had their refresh token revoked at {cloudtrail_event["eventTime"]}')
    except KeyError:
        pass
# Out:
# User "f98e24c8-2011-70ae-9d93-084eb3f4b282" had their refresh token revoked at 2025-05-22T01:53:34Z
# User "f98e24c8-2011-70ae-9d93-084eb3f4b282" had their refresh token revoked at 2025-05-22T01:53:09Z
# User "f98e24c8-2011-70ae-9d93-084eb3f4b282" had their refresh token revoked at 2025-05-22T01:52:20Z
# User "f98e24c8-2011-70ae-9d93-084eb3f4b282" had their refresh token revoked at 2025-05-22T01:51:15Z
# User "f98e24c8-2011-70ae-9d93-084eb3f4b282" had their refresh token revoked at 2025-05-22T01:35:14Z
# User "f98e24c8-2011-70ae-9d93-084eb3f4b282" had their refresh token revoked at 2025-05-22T01:35:02Z
# User "f98e24c8-2011-70ae-9d93-084eb3f4b282" had their refresh token revoked at 2025-05-22T01:20:29Z
# User "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" had their refresh token revoked at 2025-05-02T06:18:43Z
# User "f99e5408-00d1-70b5-e2aa-23d6b2a31c4f" had their refresh token revoked at 2025-05-02T03:15:12Z
# User "f98e24c8-2011-70ae-9d93-084eb3f4b282" had their refresh token revoked at 2025-05-01T01:20:09Z

# %% [markdown]
# ## How to get user details from the sub

# %%
# Run this command in the cli with the keys
# aws cognito-idp list-users --user-pool-id ap-southeast-2_3ZrrcagIG --filter "sub = \"f98e24c8-2011-70ae-9d93-084eb3f4b282\"" --region ap-southeast-2

# Update region and the user pool id as required

# {
#     "Users": [
#         {
#             "Username": "admin@example.com",
#             "Attributes": [
#                 {
#                     "Name": "email",
#                     "Value": "admin@example.com"
#                 },
#                 {
#                     "Name": "email_verified",
#                     "Value": "true"
#                 },
#                 {
#                     "Name": "family_name",
#                     "Value": "Admin"
#                 },
#                 {
#                     "Name": "given_name",
#                     "Value": "Admin"
#                 },
#                 {
#                     "Name": "custom:terraform",
#                     "Value": "true"
#                 },
#                 {
#                     "Name": "custom:identity_id",
#                     "Value": "ap-southeast-2:099e873d-80b5-cb64-b9b4-0f64c663bd46"
#                 },
#                 {
#                     "Name": "sub",
#                     "Value": "f98e24c8-2011-70ae-9d93-084eb3f4b282"
#                 }
#             ],
#             "UserCreateDate": "2024-11-20T15:58:30.157000+10:30",
#             "UserLastModifiedDate": "2025-03-13T15:09:11.817000+10:30",
#             "Enabled": true,
#             "UserStatus": "CONFIRMED"
#         }
#     ]
# }
