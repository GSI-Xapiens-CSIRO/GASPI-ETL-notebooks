# %% [markdown]
# ## Downloading Data from S3 and HTTPS
#
# #### In this tutorial, we will learn how to:
# #### - Download datasets from an HTTPS URL
# #### - Access data stored in an AWS S3 bucket
#
# ## Let's get started!

# %% [markdown]
# ## 1. Importing Necessary Libraries

# %%
#pip install boto3

# %%
import pandas as pd
import json
import boto3  # AWS SDK for Python
from io import StringIO  # For handling in-memory CSV data
import requests  # For downloading data from HTTPS

# %% [markdown]
# ## 2. Downloading Data from S3 URL
#
# #### To access data from an S3 bucket, we need:
# #### - AWS credentials (access key and secret key)
# #### - The bucket name and object key (file name)

# %%
s3_url = "s3://gaspi-dataportal-20250110044710445000000002/projects/diabetes/diabetes_cohort1.json"

# Extract bucket name and object key from the S3 URL
s3_bucket_name = "gaspi-dataportal-20250110044710445000000002"
s3_object_key = "projects/diabetes/diabetes_cohort1.json"

# AWS credentials (ensure these are set up properly in your AWS account)
aws_access_key_id = "INSERT_YOUR_KEY_HERE"  # Replace with your AWS access key
aws_secret_access_key = "INSERT_YOUR_SECRET_ACCESS_KEY_HERE"  # Replace with your AWS secret key

# Initialize the S3 client
s3 = boto3.client(
    "s3",
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
)

try:
    # Fetch the file from S3
    s3_object = s3.get_object(Bucket=s3_bucket_name, Key=s3_object_key)
    
    # Read the JSON content
    json_data = json.loads(s3_object["Body"].read().decode("utf-8"))
    
    # Convert JSON to a Pandas DataFrame (assuming it's a list of records)
    #df = pd.DataFrame(json_data)
    
    print("\nData downloaded from S3 successfully!")
    #print(json_data)
except Exception as e:
    print(f"Failed to download data from S3. Error: {e}")
# Out:
# Data downloaded from S3 successfully!

# %%
json_data
# Out:
# {'index': False,
#  'datasetId': 'DIABETES-1',
#  'dataset': {'id': 'DIABETES-1',
#   'createDateTime': '2021-03-21T02:37:00-08:00',
#   'dataUseConditions': {'duoDataUse': [{'id': 'DUO:0000042',
#      'label': 'general research use',
#      'version': '17-07-2016'}]},
#   'description': 'Simulation set 1.',
#   'externalUrl': 'http://example.org/wiki/Main_Page',
#   'info': {'svep_data': 's3://sbeacontestdata/vcf_diabetes_svep.csv'},
#   'name': 'Dataset with diabetes data',
#   'updateDateTime': '2022-08-05T17:21:00+01:00',
#   'version': 'v1.1'},
#  'assemblyId': 'GRCH38',
#  'vcfLocations': ['s3://sbeacontestdata/vcf_diabetes-1.vcf.gz'],
#  'individuals': [{'id': 'dia-individual-1-1',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-2',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-3',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-4',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-5',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-6',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-7',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-8',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-9',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-10',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-11',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-12',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-13',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-14',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-15',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-16',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-17',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-18',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-19',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-20',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-21',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-22',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-23',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-24',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-25',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-26',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-27',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-28',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-29',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-30',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-31',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-32',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-33',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-34',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-35',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-36',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-37',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-38',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-39',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-40',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-41',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-42',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-43',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-44',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-45',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-46',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-47',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-48',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-49',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-50',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-51',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-52',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-53',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-54',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-55',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-56',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-57',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-58',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-59',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-60',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-61',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-62',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-63',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-64',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-65',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-66',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-67',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-68',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-69',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-70',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-71',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-72',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-73',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-74',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-75',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-76',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-77',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-78',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-79',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-80',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-81',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-82',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-83',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-84',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-85',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-86',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-87',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:248152002', 'label': 'Female'}},
#   {'id': 'dia-individual-1-88',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-89',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-90',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:14045001', 'label': 'Caucasian'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225953001',
#       'label': 'Evaluating response to treatment'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-91',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-92',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:225970009',
#       'label': 'Evaluating progress with personal care'}}],
#    'karyotypicSex': 'XY',
#    'sex': {'id': 'SNOMED:248153007', 'label': 'Male'}},
#   {'id': 'dia-individual-1-93',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
#    'geographicOrigin': {'id': 'SNOMED:223621005', 'label': 'Australia'},
#    'interventionsOrProcedures': [{'procedureCode': {'id': 'SNOMED:1135921000168108',
#       'label': 'Rescue percutaneous coronary intervention'}}],
#    'karyotypicSex': 'XX',
#    'sex': {'id': 'SNOMED:407374003', 'label': 'Transsexual'}},
#   {'id': 'dia-individual-1-94',
#    'diseases': [{'diseaseCode': {'id': 'SNOMED:73211009',
#       'label': 'Diabetes mellitus (disorder)'}}],
#    'ethnicity': {'id': 'SNOMED:15086000', 'label': 'African American'},
# ...
#    'individualId': 'dia-individual-1-81',
#    'biosampleId': 'biosample-1-dia-individual-1-81',
#    'runId': 'run-1-biosample-1-dia-individual-1-81',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_81'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-82',
#    'individualId': 'dia-individual-1-82',
#    'biosampleId': 'biosample-1-dia-individual-1-82',
#    'runId': 'run-1-biosample-1-dia-individual-1-82',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_82'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-83',
#    'individualId': 'dia-individual-1-83',
#    'biosampleId': 'biosample-1-dia-individual-1-83',
#    'runId': 'run-1-biosample-1-dia-individual-1-83',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_83'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-84',
#    'individualId': 'dia-individual-1-84',
#    'biosampleId': 'biosample-1-dia-individual-1-84',
#    'runId': 'run-1-biosample-1-dia-individual-1-84',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_84'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-85',
#    'individualId': 'dia-individual-1-85',
#    'biosampleId': 'biosample-1-dia-individual-1-85',
#    'runId': 'run-1-biosample-1-dia-individual-1-85',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_85'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-86',
#    'individualId': 'dia-individual-1-86',
#    'biosampleId': 'biosample-1-dia-individual-1-86',
#    'runId': 'run-1-biosample-1-dia-individual-1-86',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_86'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-87',
#    'individualId': 'dia-individual-1-87',
#    'biosampleId': 'biosample-1-dia-individual-1-87',
#    'runId': 'run-1-biosample-1-dia-individual-1-87',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_87'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-88',
#    'individualId': 'dia-individual-1-88',
#    'biosampleId': 'biosample-1-dia-individual-1-88',
#    'runId': 'run-1-biosample-1-dia-individual-1-88',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_88'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-89',
#    'individualId': 'dia-individual-1-89',
#    'biosampleId': 'biosample-1-dia-individual-1-89',
#    'runId': 'run-1-biosample-1-dia-individual-1-89',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_89'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-90',
#    'individualId': 'dia-individual-1-90',
#    'biosampleId': 'biosample-1-dia-individual-1-90',
#    'runId': 'run-1-biosample-1-dia-individual-1-90',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_90'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-91',
#    'individualId': 'dia-individual-1-91',
#    'biosampleId': 'biosample-1-dia-individual-1-91',
#    'runId': 'run-1-biosample-1-dia-individual-1-91',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_91'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-92',
#    'individualId': 'dia-individual-1-92',
#    'biosampleId': 'biosample-1-dia-individual-1-92',
#    'runId': 'run-1-biosample-1-dia-individual-1-92',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_92'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-93',
#    'individualId': 'dia-individual-1-93',
#    'biosampleId': 'biosample-1-dia-individual-1-93',
#    'runId': 'run-1-biosample-1-dia-individual-1-93',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_93'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-94',
#    'individualId': 'dia-individual-1-94',
#    'biosampleId': 'biosample-1-dia-individual-1-94',
#    'runId': 'run-1-biosample-1-dia-individual-1-94',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_94'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-95',
#    'individualId': 'dia-individual-1-95',
#    'biosampleId': 'biosample-1-dia-individual-1-95',
#    'runId': 'run-1-biosample-1-dia-individual-1-95',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_95'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-96',
#    'individualId': 'dia-individual-1-96',
#    'biosampleId': 'biosample-1-dia-individual-1-96',
#    'runId': 'run-1-biosample-1-dia-individual-1-96',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_96'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-97',
#    'individualId': 'dia-individual-1-97',
#    'biosampleId': 'biosample-1-dia-individual-1-97',
#    'runId': 'run-1-biosample-1-dia-individual-1-97',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_97'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-98',
#    'individualId': 'dia-individual-1-98',
#    'biosampleId': 'biosample-1-dia-individual-1-98',
#    'runId': 'run-1-biosample-1-dia-individual-1-98',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_98'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-99',
#    'individualId': 'dia-individual-1-99',
#    'biosampleId': 'biosample-1-dia-individual-1-99',
#    'runId': 'run-1-biosample-1-dia-individual-1-99',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_99'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-100',
#    'individualId': 'dia-individual-1-100',
#    'biosampleId': 'biosample-1-dia-individual-1-100',
#    'runId': 'run-1-biosample-1-dia-individual-1-100',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_100'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-101',
#    'individualId': 'dia-individual-1-101',
#    'biosampleId': 'biosample-1-dia-individual-1-101',
#    'runId': 'run-1-biosample-1-dia-individual-1-101',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_101'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-102',
#    'individualId': 'dia-individual-1-102',
#    'biosampleId': 'biosample-1-dia-individual-1-102',
#    'runId': 'run-1-biosample-1-dia-individual-1-102',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_102'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-103',
#    'individualId': 'dia-individual-1-103',
#    'biosampleId': 'biosample-1-dia-individual-1-103',
#    'runId': 'run-1-biosample-1-dia-individual-1-103',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_103'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-104',
#    'individualId': 'dia-individual-1-104',
#    'biosampleId': 'biosample-1-dia-individual-1-104',
#    'runId': 'run-1-biosample-1-dia-individual-1-104',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_104'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-105',
#    'individualId': 'dia-individual-1-105',
#    'biosampleId': 'biosample-1-dia-individual-1-105',
#    'runId': 'run-1-biosample-1-dia-individual-1-105',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_105'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-106',
#    'individualId': 'dia-individual-1-106',
#    'biosampleId': 'biosample-1-dia-individual-1-106',
#    'runId': 'run-1-biosample-1-dia-individual-1-106',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_106'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-107',
#    'individualId': 'dia-individual-1-107',
#    'biosampleId': 'biosample-1-dia-individual-1-107',
#    'runId': 'run-1-biosample-1-dia-individual-1-107',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_107'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-108',
#    'individualId': 'dia-individual-1-108',
#    'biosampleId': 'biosample-1-dia-individual-1-108',
#    'runId': 'run-1-biosample-1-dia-individual-1-108',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_108'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-109',
#    'individualId': 'dia-individual-1-109',
#    'biosampleId': 'biosample-1-dia-individual-1-109',
#    'runId': 'run-1-biosample-1-dia-individual-1-109',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_109'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-110',
#    'individualId': 'dia-individual-1-110',
#    'biosampleId': 'biosample-1-dia-individual-1-110',
#    'runId': 'run-1-biosample-1-dia-individual-1-110',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_110'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-111',
#    'individualId': 'dia-individual-1-111',
#    'biosampleId': 'biosample-1-dia-individual-1-111',
#    'runId': 'run-1-biosample-1-dia-individual-1-111',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_111'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-112',
#    'individualId': 'dia-individual-1-112',
#    'biosampleId': 'biosample-1-dia-individual-1-112',
#    'runId': 'run-1-biosample-1-dia-individual-1-112',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_112'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-113',
#    'individualId': 'dia-individual-1-113',
#    'biosampleId': 'biosample-1-dia-individual-1-113',
#    'runId': 'run-1-biosample-1-dia-individual-1-113',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_113'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-114',
#    'individualId': 'dia-individual-1-114',
#    'biosampleId': 'biosample-1-dia-individual-1-114',
#    'runId': 'run-1-biosample-1-dia-individual-1-114',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_114'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-115',
#    'individualId': 'dia-individual-1-115',
#    'biosampleId': 'biosample-1-dia-individual-1-115',
#    'runId': 'run-1-biosample-1-dia-individual-1-115',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_115'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-116',
#    'individualId': 'dia-individual-1-116',
#    'biosampleId': 'biosample-1-dia-individual-1-116',
#    'runId': 'run-1-biosample-1-dia-individual-1-116',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_116'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-117',
#    'individualId': 'dia-individual-1-117',
#    'biosampleId': 'biosample-1-dia-individual-1-117',
#    'runId': 'run-1-biosample-1-dia-individual-1-117',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_117'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-118',
#    'individualId': 'dia-individual-1-118',
#    'biosampleId': 'biosample-1-dia-individual-1-118',
#    'runId': 'run-1-biosample-1-dia-individual-1-118',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_118'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-119',
#    'individualId': 'dia-individual-1-119',
#    'biosampleId': 'biosample-1-dia-individual-1-119',
#    'runId': 'run-1-biosample-1-dia-individual-1-119',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_119'},
#   {'id': 'analysis-1-run-1-biosample-1-dia-individual-1-120',
#    'individualId': 'dia-individual-1-120',
#    'biosampleId': 'biosample-1-dia-individual-1-120',
#    'runId': 'run-1-biosample-1-dia-individual-1-120',
#    'aligner': 'bwa-0.7.8',
#    'analysisDate': '2023-12-31',
#    'pipelineName': 'pipeline 5',
#    'pipelineRef': 'Example',
#    'variantCaller': 'SoapSNP',
#    'vcfSampleId': 'DIABETES-1_120'}]}
